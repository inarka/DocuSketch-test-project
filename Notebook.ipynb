# %%
file_path = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json'

# %%
from plotter import Plotter

# %%
plotter = Plotter()
plot_paths = plotter.draw_plots(file_path)
print(plot_paths)
# Out:
# ['plots\\Scatter plot gt_corners vs rb_corners.png', 'plots\\Scatter plot gt_corners vs mean.png', 'plots\\Scatter plot floor_mean vs ceiling_mean.png', 'plots\\Histogram for mean.png', 'plots\\Histogram for floor_mean.png', 'plots\\Histogram for ceiling_mean.png', 'plots\\Boxplots for stats.png', 'plots\\Boxplots for means.png', 'plots\\Boxplots for floor stats.png', 'plots\\Boxplots for ceiling stats.png', 'plots\\Boxplots for Floor vs Ceiling.png', 'plots\\Top 10 best results for mean.png', 'plots\\Top 10 worst results for mean.png']
