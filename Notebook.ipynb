# %%
from plotter import Plotter

# %%
file_path = 'deviation.json'

# %%
plotter = Plotter()
plot_paths = plotter.draw_plots(file_path)

# %%
plot_paths
# Out:
# ['plots\\Scatter_plot_gt_corners_vs_rb_corners.png',
#  'plots\\Scatter_plot_gt_corners_vs_mean.png',
#  'plots\\Scatter_plot_floor_mean_vs_ceiling_mean.png',
#  'plots\\Histogram_for_mean.png',
#  'plots\\Histogram_for_floor_mean.png',
#  'plots\\Histogram_for_ceiling_mean.png',
#  'plots\\Boxplots_for_stats.png',
#  'plots\\Boxplots_for_means.png',
#  'plots\\Boxplots_for_floor_stats.png',
#  'plots\\Boxplots_for_ceiling_stats.png',
#  'plots\\Boxplots_for_Floor_vs_Ceiling.png',
#  'plots\\Top_10_best_results_for_mean.png',
#  'plots\\Top_10_worst_results_for_mean.png']
